# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

import fidle.pwk as pwk

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("x_train : ",x_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",x_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 28, 28)
# y_train :  (60000,)
# x_test  :  (10000, 28, 28)
# y_test  :  (10000,)

# %%
plt.hist(y_train)
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918., 6265., 5851.,
#         5949.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
pwk.plot_images(x_train, y_train, [27],  x_size=5,y_size=5, colorbar=True, save_as='01-one-digit')
pwk.plot_images(x_train, y_train, range(5,41), columns=12, save_as='02-many-digits')

# %%
#hidden1     = 100
#hidden2     = 100

model = keras.Sequential([
#    keras.layers.Input((28,28)),
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense( 100, activation='relu'),
    keras.layers.Dense( 100, activation='relu'),
    keras.layers.Dense( 90, activation='relu'),
    keras.layers.Dense( 10, activation='softmax')
])

model.compile(optimizer='adam', #gradient descent https://keras.io/api/optimizers/
              loss='sparse_categorical_crossentropy', #cost function https://keras.io/api/losses/
              metrics=['accuracy']) #https://keras.io/api/metrics/

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 90)                9090
#
#  dense_3 (Dense)             (None, 10)                910
#
# =================================================================
# Total params: 98,600
# Trainable params: 98,600
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size  = 512 #nb of samples through the network at the same time
epochs      =  16 #nb of iterations

history = model.fit(  x_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      verbose         = 1,
                      validation_data = (x_test, y_test))
# Out:
# Epoch 1/16
# 118/118 [==============================] - 3s 15ms/step - loss: 0.5485 - accuracy: 0.8438 - val_loss: 0.2340 - val_accuracy: 0.9329
# Epoch 2/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.1920 - accuracy: 0.9440 - val_loss: 0.1584 - val_accuracy: 0.9531
# Epoch 3/16
# 118/118 [==============================] - 1s 12ms/step - loss: 0.1411 - accuracy: 0.9588 - val_loss: 0.1340 - val_accuracy: 0.9593
# Epoch 4/16
# 118/118 [==============================] - 1s 12ms/step - loss: 0.1109 - accuracy: 0.9671 - val_loss: 0.1095 - val_accuracy: 0.9664
# Epoch 5/16
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0906 - accuracy: 0.9727 - val_loss: 0.1034 - val_accuracy: 0.9685
# Epoch 6/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0788 - accuracy: 0.9764 - val_loss: 0.0881 - val_accuracy: 0.9734
# Epoch 7/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0658 - accuracy: 0.9800 - val_loss: 0.0873 - val_accuracy: 0.9743
# Epoch 8/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0576 - accuracy: 0.9826 - val_loss: 0.0890 - val_accuracy: 0.9739
# Epoch 9/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0812 - val_accuracy: 0.9753
# Epoch 10/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0429 - accuracy: 0.9869 - val_loss: 0.0891 - val_accuracy: 0.9750
# Epoch 11/16
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0375 - accuracy: 0.9889 - val_loss: 0.0866 - val_accuracy: 0.9748
# Epoch 12/16
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0339 - accuracy: 0.9903 - val_loss: 0.0768 - val_accuracy: 0.9772
# Epoch 13/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0285 - accuracy: 0.9914 - val_loss: 0.0870 - val_accuracy: 0.9736
# Epoch 14/16
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0820 - val_accuracy: 0.9753
# Epoch 15/16
# 118/118 [==============================] - 1s 11ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 0.0911 - val_accuracy: 0.9741
# Epoch 16/16
# 118/118 [==============================] - 1s 10ms/step - loss: 0.0211 - accuracy: 0.9940 - val_loss: 0.0850 - val_accuracy: 0.9760

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss     :', score[0])
print('Test accuracy :', score[1])
# Out:
# Test loss     : 0.08503612130880356
# Test accuracy : 0.9760000109672546

# %%
pwk.plot_history(history,  plot={'Acc':['accuracy','val_accuracy'],'Loss':['loss','val_loss']})

# %%
#y_pred   = model.predict_classes(x_test)           Deprecated after 01/01/2021 !!

y_sigmoid = model.predict(x_test)
y_pred    = np.argmax(y_sigmoid, axis=-1)

pwk.plot_images(x_test, y_test, range(0,200), columns=12, x_size=1, y_size=1, y_pred=y_pred, save_as='04-predictions')
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
errors=[ i for i in range(len(x_test)) if y_pred[i]!=y_test[i] ]
errors=errors[:min(24,len(errors))]
pwk.plot_images(x_test, y_test, errors[:15], columns=6, x_size=2, y_size=2, y_pred=y_pred, save_as='05-some-errors')

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
# import scikitplot as skplt 

print(classification_report(y_test,y_pred))
print(accuracy_score(y_test,y_pred))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.97      1032
#            3       0.96      0.98      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.97      0.98      0.97       892
#            6       0.98      0.97      0.98       958
#            7       0.99      0.96      0.98      1028
#            8       0.96      0.98      0.97       974
#            9       0.97      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
# 0.976
